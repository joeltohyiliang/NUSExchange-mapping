# %%
import pandas as pd
import numpy as np
import os 

os.chdir('D:\OneDrive - National University of Singapore\exchange')

dataset = pd.read_csv (r'D:\OneDrive - National University of Singapore\exchange\ps1.csv')
modlist = pd.read_excel(r'D:\OneDrive - National University of Singapore\exchange\Book1.xlsx')
print(dataset)
# Out:
#                   Faculty                                Partner University  \
# 0     School of Computing              The Hong Kong Polytechnic University
# 1     School of Computing              The Hong Kong Polytechnic University
# 2     School of Computing              The Hong Kong Polytechnic University
# 3     School of Computing              The Hong Kong Polytechnic University
# 4     School of Computing              The Hong Kong Polytechnic University
# 5     School of Computing              The Hong Kong Polytechnic University
# 6     School of Computing      Hong Kong University of Science & Technology
# 7     School of Computing      Hong Kong University of Science & Technology
# 8     School of Computing      Hong Kong University of Science & Technology
# 9     School of Computing      Hong Kong University of Science & Technology
# 10    School of Computing      Hong Kong University of Science & Technology
# ...

# %%
df = dataset.loc[(dataset['NUS Module 1'].isin(modlist['MODS']))]
print(df)
df.to_csv('df_result.csv', header = True)
# Out:
#                   Faculty                             Partner University  \
# 0     School of Computing           The Hong Kong Polytechnic University
# 1     School of Computing           The Hong Kong Polytechnic University
# 3     School of Computing           The Hong Kong Polytechnic University
# 9     School of Computing   Hong Kong University of Science & Technology
# 10    School of Computing   Hong Kong University of Science & Technology
# 18    School of Computing   Hong Kong University of Science & Technology
# 23    School of Computing   Hong Kong University of Science & Technology
# 24    School of Computing   Hong Kong University of Science & Technology
# 29    School of Computing   Hong Kong University of Science & Technology
# 36    School of Computing                   City University of Hong Kong
# 37    School of Computing                   City University of Hong Kong
# 38    School of Computing                   City University of Hong Kong
# ...
